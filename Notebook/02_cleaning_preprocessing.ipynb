# %% [markdown]
# ## DATA CLEANING & PREPROCESSING

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\LENOVO\OneDrive\Desktop\eda mini project\Data\Raw\Amazon.csv")
df.head()
# Out:
#       OrderID   OrderDate  CustomerID   CustomerName ProductID  \
# 0  ORD0000001  31-01-2023  CUST001504  Vihaan Sharma    P00014
# 1  ORD0000002  30-12-2023  CUST000178    Pooja Kumar    P00040
# 2  ORD0000003  10-05-2022  CUST047516    Sneha Singh    P00044
# 3  ORD0000004  18-07-2023  CUST030059   Vihaan Reddy    P00041
# 4  ORD0000005  04-02-2023  CUST048677  Aditya Kapoor    P00029
#
#            ProductName        Category       Brand  Quantity  UnitPrice  \
# 0           Drone Mini           Books   BrightLux         3     106.59
# 1           Microphone  Home & Kitchen  UrbanStyle         1     251.37
# 2  Power Bank 20000mAh        Clothing  UrbanStyle         3      35.03
# 3       Webcam Full HD  Home & Kitchen      Zenith         5      33.58
# 4              T-Shirt        Clothing    KiddoFun         2     515.64
#
#    Discount    Tax  ShippingCost  TotalAmount     PaymentMethod OrderStatus  \
# ...

# %%
df.shape
# Out:
# (100000, 20)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 20 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   OrderID        100000 non-null  str
#  1   OrderDate      100000 non-null  str
#  2   CustomerID     100000 non-null  str
#  3   CustomerName   100000 non-null  str
#  4   ProductID      100000 non-null  str
#  5   ProductName    100000 non-null  str
#  6   Category       100000 non-null  str
#  7   Brand          100000 non-null  str
#  8   Quantity       100000 non-null  int64
#  9   UnitPrice      100000 non-null  float64
#  10  Discount       100000 non-null  float64
#  11  Tax            100000 non-null  float64
#  12  ShippingCost   100000 non-null  float64
#  13  TotalAmount    100000 non-null  float64
#  14  PaymentMethod  100000 non-null  str
#  15  OrderStatus    100000 non-null  str
#  16  City           100000 non-null  str
#  17  State          100000 non-null  str
# ...

# %%
df.isnull().sum()

# %% [markdown]
# ## Missing Value Treatment
#
# No missing values were found in the dataset. Therefore, no imputation techniques were required.

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Duplicate Handling
#
# No duplicate records were found in the dataset. Hence, no duplicate removal was necessary.

# %%
df["OrderDate"] = pd.to_datetime(df["OrderDate"], dayfirst=True)

# %% [markdown]
# ## Data Type Conversion
#
# The OrderDate column was converted from string to datetime format to enable time-based analysis.

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 20 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   OrderID        100000 non-null  str
#  1   OrderDate      100000 non-null  datetime64[us]
#  2   CustomerID     100000 non-null  str
#  3   CustomerName   100000 non-null  str
#  4   ProductID      100000 non-null  str
#  5   ProductName    100000 non-null  str
#  6   Category       100000 non-null  str
#  7   Brand          100000 non-null  str
#  8   Quantity       100000 non-null  int64
#  9   UnitPrice      100000 non-null  float64
#  10  Discount       100000 non-null  float64
#  11  Tax            100000 non-null  float64
#  12  ShippingCost   100000 non-null  float64
#  13  TotalAmount    100000 non-null  float64
#  14  PaymentMethod  100000 non-null  str
#  15  OrderStatus    100000 non-null  str
#  16  City           100000 non-null  str
# ...

# %%
df["Category"] = df["Category"].str.strip()
df["Brand"] = df["Brand"].str.strip()
df["PaymentMethod"] = df["PaymentMethod"].str.strip()
df["OrderStatus"] = df["OrderStatus"].str.strip()
df["City"] = df["City"].str.strip()
df["State"] = df["State"].str.strip()
df["Country"] = df["Country"].str.strip()

# %% [markdown]
# ## Categorical Data Cleaning
#
# Leading and trailing spaces were removed from categorical columns such as Category, Brand, PaymentMethod, OrderStatus, City, State, and Country to ensure consistency.

# %%
Q1 = df["TotalAmount"].quantile(0.25)
Q3 = df["TotalAmount"].quantile(0.75)

IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

outliers = df[(df["TotalAmount"] < lower) | (df["TotalAmount"] > upper)]

outliers.shape
# Out:
# (1360, 20)

# %% [markdown]
# ## Outlier Detection and Treatment
#
# Outliers in the TotalAmount column were identified using the IQR method.
#
# Records outside the acceptable range were removed to improve data quality and ensure accurate analysis.

# %%
df = df[(df["TotalAmount"] >= lower) & (df["TotalAmount"] <= upper)]

# %%
df.shape
# Out:
# (98640, 20)

# %% [markdown]
# ## Final Dataset After Cleaning
#
# After removing outliers, the dataset size was reduced from 100,000 rows to 98,640 rows, ensuring better data quality.

# %%
df.to_csv(r"C:\Users\LENOVO\OneDrive\Desktop\eda mini project\Data\Interim\cleaned_day2.csv", index=False)
